# %%
# [CELL 1] PASSWORD

SURNAME = "dela Cruz"
STUDENT_ID = "TUPM-26-1839"
SEED_NUM = SEED_NUM = int(STUDENT_ID[-1])

print(f"System Initialized for: {SURNAME}")
print(f"System Initialized for: {STUDENT_ID}")
print(f"Algorithmic Seed Value: {SEED_NUM}")

while True:
    pwd = input("Type 'SURNAME + SEED_NUM' to open: ")
if pwd == 'SURNAME + SEED_NUM':
    print(f"ACCESS GRANTED!")
    break # Break terminates the infinite loop
else: 
    print(f"ENGGKKK MALI!")
# Out:
# System Initialized for: dela Cruz
# System Initialized for: TUPM-26-1839
# Algorithmic Seed Value: 9
